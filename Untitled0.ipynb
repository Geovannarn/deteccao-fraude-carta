# %% [markdown]
# <a href="https://colab.research.google.com/github/Geovannarn/deteccao-fraude-carta/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost shap imbalanced-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_curve, roc_auc_score,
    precision_recall_curve, average_precision_score,
    f1_score, precision_score, recall_score
)
import xgboost as xgb
import shap

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

RANDOM_STATE = 42

# %%
import pandas as pd

url = "https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
df['Class'].value_counts(normalize=True) * 100
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df['Class'].value_counts(normalize=True) * 100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

prop = df['Class'].value_counts(normalize=True) * 100
print(prop)

sns.countplot(x='Class', data=df)
plt.title('Distribuição de Transações: Normal (0) vs Fraude (1)')
plt.ylabel('Quantidade')
plt.xlabel('Classe')
plt.show()
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
df['Amount_log'] = np.log1p(df['Amount'])

scaler = StandardScaler()
df['Time_scaled'] = scaler.fit_transform(df[['Time']])
df['Amount_scaled'] = scaler.fit_transform(df[['Amount_log']])

df[['Time', 'Time_scaled', 'Amount', 'Amount_log', 'Amount_scaled']].head()
# Out:
#    Time  Time_scaled  Amount  Amount_log  Amount_scaled
# 0   0.0    -1.996583  149.62    5.014760       1.124303
# 1   0.0    -1.996583    2.69    1.305626      -1.114639
# 2   1.0    -1.996562  378.66    5.939276       1.682368
# 3   1.0    -1.996562  123.50    4.824306       1.009339
# 4   2.0    -1.996541   69.99    4.262539       0.670241

# %%
df.info()
print("\nValores nulos por coluna:")
print(df.isnull().sum().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 34 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Time           284807 non-null  float64
#  1   V1             284807 non-null  float64
#  2   V2             284807 non-null  float64
#  3   V3             284807 non-null  float64
#  4   V4             284807 non-null  float64
#  5   V5             284807 non-null  float64
#  6   V6             284807 non-null  float64
#  7   V7             284807 non-null  float64
#  8   V8             284807 non-null  float64
#  9   V9             284807 non-null  float64
#  10  V10            284807 non-null  float64
#  11  V11            284807 non-null  float64
#  12  V12            284807 non-null  float64
#  13  V13            284807 non-null  float64
#  14  V14            284807 non-null  float64
#  15  V15            284807 non-null  float64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_curve, roc_auc_score,
    precision_recall_curve, average_precision_score,
    f1_score, precision_score, recall_score
)
import xgboost as xgb
import shap

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

RANDOM_STATE = 42

# %%
def avaliar_modelo(nome, y_true, y_pred, y_proba):
    print(f"===== {nome} =====")
    print(classification_report(y_true, y_pred, target_names=['Normal', 'Fraude']))

    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal', 'Fraude'], yticklabels=['Normal', 'Fraude'])
    plt.title(f'Matriz de Confusão - {nome}')
    plt.ylabel('Real')
    plt.xlabel('Previsto')
    plt.show()

    fpr, tpr, _ = roc_curve(y_true, y_proba)
    auc = roc_auc_score(y_true, y_proba)
    plt.plot(fpr, tpr, label=f'{nome} (AUC = {auc:.4f})')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('Falso Positivo')
    plt.ylabel('Verdadeiro Positivo')
    plt.title(f'Curva ROC - {nome}')
    plt.legend()
    plt.show()

    prec, rec, _ = precision_recall_curve(y_true, y_proba)
    ap = average_precision_score(y_true, y_proba)
    plt.plot(rec, prec, label=f'{nome} (AP = {ap:.4f})')
    plt.xlabel('Recall')
    plt.ylabel('Precisão')
    plt.title(f'Curva Precisão-Recall - {nome}')
    plt.legend()
    plt.show()

    return {
        'modelo': nome,
        'recall_fraude': recall_score(y_true, y_pred),
        'precisao_fraude': precision_score(y_true, y_pred),
        'f1_fraude': f1_score(y_true, y_pred),
        'auc_roc': auc,
        'auc_pr': ap
    }

resultados = []

# %%
df['Amount_log'] = np.log1p(df['Amount'])

scaler = StandardScaler()
df['Time_scaled'] = scaler.fit_transform(df[['Time']])
df['Amount_scaled'] = scaler.fit_transform(df[['Amount_log']])

# %%
X = df.drop(columns=['Class', 'Time', 'Amount', 'Amount_log'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y)

log_reg = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=RANDOM_STATE)
log_reg.fit(X_train, y_train)

y_proba_lr = log_reg.predict_proba(X_test)[:, 1]
y_pred_lr = (y_proba_lr >= 0.5).astype(int)

resultados.append(avaliar_modelo("Regressão Logística", y_test, y_pred_lr, y_proba_lr))
# Out:
# ===== Regressão Logística =====
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     56864
#       Fraude       0.06      0.92      0.11        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.95      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
X = df.drop(columns=['Class', 'Time', 'Amount', 'Amount_log'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y)

rf = RandomForestClassifier(
    n_estimators=100, class_weight='balanced',
    random_state=RANDOM_STATE, n_jobs=-1
)
rf.fit(X_train, y_train)

y_proba_rf = rf.predict_proba(X_test)[:, 1]
y_pred_rf = (y_proba_rf >= 0.5).astype(int)

resultados.append(avaliar_modelo("Random Forest", y_test, y_pred_rf, y_proba_rf))
# Out:
# ===== Random Forest =====
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     56864
#       Fraude       0.96      0.74      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.87      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
X = df.drop(columns=['Class', 'Time', 'Amount', 'Amount_log'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y)

scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

xgb_model = xgb.XGBClassifier(
    scale_pos_weight=scale_pos_weight,
    eval_metric='logloss',
    random_state=RANDOM_STATE
)
xgb_model.fit(X_train, y_train)

y_proba_xgb = xgb_model.predict_proba(X_test)[:, 1]
y_pred_xgb = (y_proba_xgb >= 0.5).astype(int)

resultados.append(avaliar_modelo("XGBoost", y_test, y_pred_xgb, y_proba_xgb))
# Out:
# ===== XGBoost =====
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     56864
#       Fraude       0.89      0.83      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.91      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
thresholds = [0.5, 0.4, 0.3, 0.2, 0.1]
resultados_threshold = []

for t in thresholds:
    y_pred_t = (y_proba_xgb >= t).astype(int)
    resultados_threshold.append({
        'threshold': t,
        'recall': recall_score(y_test, y_pred_t),
        'precisao': precision_score(y_test, y_pred_t),
        'f1': f1_score(y_test, y_pred_t)
    })

df_threshold = pd.DataFrame(resultados_threshold)
df_threshold
# Out:
#    threshold    recall  precisao        f1
# 0        0.5  0.826531  0.890110  0.857143
# 1        0.4  0.826531  0.880435  0.852632
# 2        0.3  0.826531  0.870968  0.848168
# 3        0.2  0.846939  0.838384  0.842640
# 4        0.1  0.846939  0.790476  0.817734

# %%
LIMIAR_ESCOLHIDO = 0.3

y_pred_final = (y_proba_xgb >= 0.3).astype(int)
print(f"===== XGBoost com limiar = {0.3} =====")
print(classification_report(y_test, y_pred_final, target_names=['Normal', 'Fraude']))
# Out:
# ===== XGBoost com limiar = 0.3 =====
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     56864
#       Fraude       0.87      0.83      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.91      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
rus = RandomUnderSampler(random_state=RANDOM_STATE)
X_train_under, y_train_under = rus.fit_resample(X_train, y_train)

rf_under = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=-1)
rf_under.fit(X_train_under, y_train_under)
y_proba_under = rf_under.predict_proba(X_test)[:, 1]
y_pred_under = (y_proba_under >= 0.5).astype(int)

print("===== Random Forest + Undersampling =====")
print(classification_report(y_test, y_pred_under, target_names=['Normal', 'Fraude']))

smote = SMOTE(random_state=RANDOM_STATE)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

rf_over = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=-1)
rf_over.fit(X_train_over, y_train_over)
y_proba_over = rf_over.predict_proba(X_test)[:, 1]
y_pred_over = (y_proba_over >= 0.5).astype(int)

print("===== Random Forest + SMOTE (Oversampling) =====")
print(classification_report(y_test, y_pred_over, target_names=['Normal', 'Fraude']))
# Out:
# ===== Random Forest + Undersampling =====
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.96      0.98     56864
#       Fraude       0.04      0.92      0.08        98
#
#     accuracy                           0.96     56962
#    macro avg       0.52      0.94      0.53     56962
# weighted avg       1.00      0.96      0.98     56962
#
# ===== Random Forest + SMOTE (Oversampling) =====
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     56864
#       Fraude       0.84      0.81      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.90      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
features = X.columns

importancias = pd.DataFrame({
    'feature': features,
    'importancia': xgb_model.feature_importances_
}).sort_values('importancia', ascending=False)

plt.figure(figsize=(10, 8))
sns.barplot(x='importancia', y='feature', data=importancias.head(15))
plt.title('Top 15 Variáveis mais Importantes - XGBoost')
plt.show()

importancias.head(15)
# Out:
#           feature  importancia
# 13            V14     0.612754
# 3              V4     0.062281
# 11            V12     0.038792
# 7              V8     0.027227
# 6              V7     0.016996
# 25            V26     0.016274
# 29  Amount_scaled     0.016093
# 19            V20     0.015984
# 9             V10     0.013229
# 26            V27     0.012403
# 12            V13     0.012267
# 17            V18     0.011054
# 18            V19     0.010910
# 16            V17     0.010902
# 2              V3     0.010878

# %%
features = X_test.columns

explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, feature_names=features)

# %%
features = X_test.columns
idx_fraude = y_test[y_test == 1].index[0]
posicao = X_test.index.get_loc(idx_fraude)

shap.force_plot(
    explainer.expected_value,
    shap_values[posicao],
    X_test.iloc[posicao],
    feature_names=features,
    matplotlib=True
)
